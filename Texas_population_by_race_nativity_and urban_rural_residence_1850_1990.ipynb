# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# open pandas read csv

# %%
texas = pd.read_csv('../Maps/Aa5872-5934.csv')
texas.head(16)
# Out:
#     Year  Area_Aa5872_SquareMiles   \
# 0   1850                    262398
# 1   1860                    262398
# 2   1870                    262398
# 3   1880                    262398
# 4   1890                    262398
# 5   1900                    262398
# 6   1910                    262398
# 7   1920                    262398
# 8   1930                    262398
# 9   1940                    263644
# 10  1950                    263513
# 11  1960                    262970
# 12  1970                    262134
# 13  1980                    262017
# 14  1990                    261914
#
#     PopulationDensity_Aa5873_PersonsPerSquareMile   \
# 0                                             0.81
# 1                                             2.30
# 2                                             3.12
# 3                                             6.07
# 4                                             8.52
# 5                                            11.62
# ...
